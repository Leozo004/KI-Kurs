# %%
import pandas as pd

data = {
    'Datum': [  '2023.01.01', '2023.01.02', '2023.01.03', '2023.01.04', '2023.01.05', 
                '2023.01.06', '2023.01.07', '2023.01.08', '2023.01.09', '2023.01.10', 
                '2023.01.11', '2023.01.12', '2023.01.13', '2023.01.14', '2023.01.15', 
                '2023.01.16', '2023.01.17', '2023.01.18', '2023.01.19', '2023.01.20', 
                '2023.01.21', '2023.01.22', '2023.01.23', '2023.01.24', '2023.01.25', 
                '2023.01.26', '2023.01.27', '2023.01.28', '2023.01.29', '2023.01.30', 
                '2023.01.31', '2023.02.01', '2023.02.02', '2023.02.03', '2023.02.04', 
                '2023.02.05', '2023.02.06', '2023.02.07', '2023.02.08', '2023.02.09', 
                '2023.02.10', '2023.02.11', '2023.02.12', '2023.02.13', '2023.02.14', 
                '2023.02.15', '2023.02.16', '2023.02.17', '2023.02.18', '2023.02.19', 
                '2023.02.20', '2023.02.21', '2023.02.22', '2023.02.23', '2023.02.24', 
                '2023.02.25', '2023.02.26', '2023.02.27', '2023.02.28', '2023.03.01', 
                '2023.03.02', '2023.03.03', '2023.03.04', '2023.03.05', '2023.03.06', 
                '2023.03.07', '2023.03.08', '2023.03.09', '2023.03.10', '2023.03.11', 
                '2023.03.12', '2023.03.13', '2023.03.14', '2023.03.15', '2023.03.16', 
                '2023.03.17', '2023.03.18', '2023.03.19', '2023.03.20', '2023.03.21', 
                '2023.03.22', '2023.03.23', '2023.03.24', '2023.03.25', '2023.03.26', 
                '2023.03.27', '2023.03.28', '2023.03.29', '2023.03.30', '2023.03.31', 
                '2023.04.01', '2023.04.02', '2023.04.03', '2023.04.04', '2023.04.05', 
                '2023.04.06', '2023.04.07', '2023.04.08', '2023.04.09', '2023.04.10', 
                '2023.04.11', '2023.04.12', '2023.04.13', '2023.04.14', '2023.04.15', 
                '2023.04.16', '2023.04.17', '2023.04.18', '2023.04.19', '2023.04.20', 
                '2023.04.21', '2023.04.22', '2023.04.23', '2023.04.24', '2023.04.25',
                '2023.04.26', '2023.04.27', '2023.04.28', '2023.04.29', '2023.04.30', 
                '2023.05.01', '2023.05.02', '2023.05.03', '2023.05.04', '2023.05.05', 
                '2023.05.06', '2023.05.07', '2023.05.08', '2023.05.09', '2023.05.10', 
                '2023.05.11', '2023.05.12', '2023.05.13', '2023.05.14', '2023.05.15', 
                '2023.05.16', '2023.05.17', '2023.05.18', '2023.05.19', '2023.05.20', 
                '2023.05.21', '2023.05.22', '2023.05.23', '2023.05.24', '2023.05.25', 
                '2023.05.26', '2023.05.27', '2023.05.28', '2023.05.29', '2023.05.30', 
                '2023.05.31', '2023.06.01', '2023.06.02', '2023.06.03', '2023.06.04', 
                '2023.06.05', '2023.06.06', '2023.06.07', '2023.06.08', '2023.06.09', 
                '2023.06.10', '2023.06.11', '2023.06.12', '2023.06.13', '2023.06.14', 
                '2023.06.15', '2023.06.16', '2023.06.17', '2023.06.18', '2023.06.19', 
                '2023.06.20', '2023.06.21', '2023.06.22', '2023.06.23', '2023.06.24', 
                '2023.06.25', '2023.06.26', '2023.06.27', '2023.06.28', '2023.06.29', 
                '2023.06.30'],
    'Min': [    '11.53', '9.49', '10.03', '10.99', '12.47', '8.97', '10.38', '11.06',
                '11.97', '10.34', '9.70', '11.00', '11.08', '10.59', '9.94', '10.18', 
                '12.18', '10.89', '10.27', '11.28', '10.93', '9.21', '11.20', '9.87', 
                '10.79', '11.06', '11.28', '10.99', '9.59', '10.40', '8.93', '11.07', 
                '10.72', '9.36', '11.38', '12.46', '11.79', '10.84', '11.00', '9.37',
                '11.06', '10.67', '9.83', '11.82', '9.78', '12.05', '10.83', '11.07', 
                '9.81', '8.82', '10.04', '10.38', '10.74', '11.70', '11.27', '10.52', 
                '11.98', '9.37', '10.49', '10.94', '11.92', '8.90', '11.60', '10.31', 
                '9.59', '11.40', '10.83', '9.90', '10.76', '10.29', '12.38', '10.92', 
                '8.91', '10.11', '11.37', '11.92', '11.59', '12.04', '9.69', '11.96', 
                '10.73', '10.69', '11.75', '10.06', '8.89', '9.69', '10.28', '11.69', 
                '9.96', '11.05', '8.99', '11.06', '11.74', '10.83', '10.32', '12.04', 
                '11.18', '9.89', '12.27', '11.28', '10.93', '10.21', '11.20', '9.87', 
                '12.08', '11.23', '10.24', '10.61', '11.23', '9.84', '11.92', '9.69', 
                '10.13', '10.69', '9.67', '11.73', '11.69', '9.83', '10.00', '11.82',
                '9.14', '11.26', '10.32', '10.58', '11.17', '11.61', '12.10', '9.24', 
                '12.01', '10.19', '10.27', '11.28', '10.93', '9.21', '11.20', '9.87', 
                '11.12', '9.64', '11.50', '8.61', '11.19', '11.68', '11.65', '10.18', 
                '10.34', '12.13', '11.24', '10.49', '8.93', '9.21', '10.90', '11.27', 
                '10.73', '11.29', '11.07', '8.93', '10.57', '9.21', '10.29', '11.18', 
                '12.03', '11.73', '10.67', '11.73', '9.33', '9.21', '10.83', '10.30', 
                '11.36', '10.15', '9.31', '12.08', '11.96', '10.47', '9.22', '12.06', 
                '11.18', '9.39', '10.83', '11.28', '10.54'],
    'Max': [    '14.53', '13.49', '14.03', '13.99', '14.47', '12.97', '14.38', '15.06', 
                '13.97', '14.34', '13.70', '14.00', '15.08', '14.59', '14.94', '13.18',
                '13.18', '13.89', '14.27', '14.28', '14.93', '14.21', '15.20', '13.87', 
                '14.79', '15.06', '14.28', '13.99', '13.59', '14.40', '13.93', '15.07', 
                '14.72', '13.36', '13.38', '14.46', '14.79', '12.84', '15.00', '14.37',
                '14.06', '14.67', '12.83', '13.82', '13.78', '12.05', '12.83', '15.07', 
                '13.81', '14.82', '14.04', '13.38', '14.74', '14.70', '14.27', '13.52', 
                '13.98', '12.37', '15.49', '14.94', '12.92', '12.90', '13.60', '14.31', 
                '15.59', '14.40', '13.83', '13.90', '14.76', '15.29', '14.38', '14.92', 
                '13.91', '13.11', '13.37', '12.92', '15.59', '15.04', '13.69', '14.96', 
                '14.73', '14.69', '13.75', '15.06', '14.89', '12.69', '13.28', '13.69', 
                '14.96', '15.05', '12.99', '13.06', '14.74', '14.83', '15.32', '14.04', 
                '15.18', '13.89', '14.27', '14.28', '14.93', '14.21', '13.20', '12.87', 
                '14.08', '14.23', '15.24', '13.61', '15.23', '14.84', '14.92', '13.69', 
                '14.13', '14.69', '13.67', '12.73', '14.69', '13.83', '15.10', '14.42',
                '14.14', '15.26', '13.32', '13.58', '14.17', '12.61', '14.12', '14.24', 
                '14.01', '14.19', '14.27', '15.28', '13.93', '12.21', '13.20', '12.87', 
                '15.12', '13.64', '14.50', '12.61', '15.19', '13.68', '14.65', '14.18', 
                '14.34', '15.13', '13.24', '13.49', '12.93', '13.21', '12.90', '13.27', 
                '14.73', '13.29', '13.07', '12.93', '13.57', '13.21', '14.29', '15.18', 
                '15.03', '13.73', '12.67', '14.73', '12.33', '13.21', '14.83', '15.30', 
                '14.36', '13.15', '12.31', '15.08', '14.96', '15.47', '14.22', '15.06', 
                '13.18', '12.39', '14.83', '14.28', '13.54']
}

#DataFrame erstellen
df = pd.DataFrame(data)

df['Range'] = df['Max'].astype(float) - df['Min'].astype(float)

#DataFrame als CSV speichern
df.to_csv('BspAusreißerErkennungDaten.csv', index = False)

#DataFrame anzeigen
print(pd.read_csv('BspAusreißerErkennungDaten.csv'))
# Out:
#           Datum    Min    Max  Range
# 0    2023.01.01  11.53  14.53    3.0
# 1    2023.01.02   9.49  13.49    4.0
# 2    2023.01.03  10.03  14.03    4.0
# 3    2023.01.04  10.99  13.99    3.0
# 4    2023.01.05  12.47  14.47    2.0
# ..          ...    ...    ...    ...
# 176  2023.06.26  11.18  13.18    2.0
# 177  2023.06.27   9.39  12.39    3.0
# 178  2023.06.28  10.83  14.83    4.0
# 179  2023.06.29  11.28  14.28    3.0
# 180  2023.06.30  10.54  13.54    3.0
#
# [181 rows x 4 columns]
